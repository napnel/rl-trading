# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
DATA_PATH = Path.home() / "data" / "BTCUSDT"

# %%
df = pd.read_pickle(DATA_PATH / "ohlcv_with_features" / "4H.pkl")
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df = pd.read_pickle(DATA_PATH / "ohlcv_with_features" / "4H_train.pkl")
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df = pd.read_pickle(DATA_PATH / "ohlcv_with_features" / "4H_test.pkl")
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>
